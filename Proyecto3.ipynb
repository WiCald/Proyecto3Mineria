# %%
pip install pyreadstat
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# Cargar el archivo SPSS (.sav)
archivo = "divorcios2023.sav"
df = pd.read_spss(archivo)

# Mostrar las primeras filas
print(df.head())

# Mostrar información de las columnas (nombres y tipos de datos)
print(df.info())

columnas_categoricas = df.select_dtypes(include=['category']).columns

# Obtener tablas de frecuencia para cada variable categórica
for col in columnas_categoricas:
    print(f"\nFrecuencia de la variable '{col}':")
    frecuencia = df[col].value_counts()
    
    print(frecuencia.head(3))
    print("...")
    print(frecuencia.tail(3))
# Out:
#           DEPREG                    MUPREG  MESREG  AÑOREG  DIAOCU   MESOCU  \
# 0  Huehuetenango             Huehuetenango   Enero  2023.0    17.0    Enero
# 1      Guatemala                 Guatemala   Marzo  2023.0     7.0  Febrero
# 2      Guatemala                 Guatemala    Mayo  2023.0    10.0    Abril
# 3   Sacatepéquez  Santa Lucía Milpas Altas   Julio  2023.0    22.0     Mayo
# 4          Petén                    Poptún  Agosto  2023.0    26.0     Mayo
#
#    AÑOOCU         DEPOCU            MUPOCU   EDADHOM EDADMUJ           PUEHOM  \
# 0  2023.0  Huehuetenango     Huehuetenango      43.0    51.0  Mestizo, Ladino
# 1  2023.0      Guatemala         Guatemala  Ignorado    53.0         Ignorado
# 2  2023.0      Guatemala         Guatemala      41.0    33.0  Mestizo, Ladino
# 3  2023.0  Chimaltenango  Tecpán Guatemala      39.0    36.0             Maya
# 4  2023.0          Petén           Dolores      30.0    34.0  Mestizo, Ladino
#
# ...

# %%
import pandas as pd

# Cargar el archivo SPSS (.sav)
archivo = "divorcios2022.sav"  # Asegúrate de que el archivo esté en la misma carpeta o usa la ruta completa
df = pd.read_spss(archivo)

# Mostrar las primeras filas
print(df.head())

# Mostrar información de las columnas (nombres y tipos de datos)
print(df.info())

# Seleccionar solo las columnas categóricas
columnas_categoricas = df.select_dtypes(include=['category']).columns

# Obtener tablas de frecuencia para cada variable categórica
for col in columnas_categoricas:
    print(f"\nFrecuencia de la variable '{col}':")
    frecuencia = df[col].value_counts()
    
    # Mostrar solo los 3 primeros y 3 últimos resultados
    print(frecuencia.head(3))
    print("...")
    print(frecuencia.tail(3))
# Out:
#       DEPREG       MUPREG      MESREG  AÑOREG  DIAOCU      MESOCU  AÑOOCU  \
# 0  Guatemala    Guatemala       Enero  2023.0    14.0   Diciembre  2022.0
# 1  Guatemala  Villa Nueva  Septiembre  2022.0    16.0      Agosto  2022.0
# 2     Zacapa       Zacapa       Enero  2023.0     7.0   Diciembre  2022.0
# 3  Guatemala    Guatemala     Octubre  2022.0    20.0  Septiembre  2022.0
# 4  Guatemala    Guatemala   Diciembre  2022.0    28.0   Noviembre  2022.0
#
#       DEPOCU     MUPOCU EDADHOM EDADMUJ           PUEHOM           PUEMUJ  \
# 0  Guatemala  Guatemala    38.0    43.0         Ignorado  Mestizo, Ladino
# 1  Guatemala  Guatemala    30.0    35.0  Mestizo, Ladino  Mestizo, Ladino
# 2  Guatemala  Guatemala    33.0    30.0  Mestizo, Ladino  Mestizo, Ladino
# 3  Guatemala  Guatemala    34.0    32.0  Mestizo, Ladino  Mestizo, Ladino
# 4  Guatemala  Guatemala    31.0    24.0  Mestizo, Ladino  Mestizo, Ladino
#
#       NACHOM     NACMUJ         ESCHOM         ESCMUJ  \
# ...

# %%
import pandas as pd

# Cargar el archivo SPSS (.sav)
archivo = "divorcios2021.sav"  # Asegúrate de que el archivo esté en la misma carpeta o usa la ruta completa
df = pd.read_spss(archivo)

# Mostrar las primeras filas
print(df.head())

# Mostrar información de las columnas (nombres y tipos de datos)
print(df.info())

# Seleccionar solo las columnas categóricas
columnas_categoricas = df.select_dtypes(include=['category']).columns

# Obtener tablas de frecuencia para cada variable categórica
for col in columnas_categoricas:
    print(f"\nFrecuencia de la variable '{col}':")
    frecuencia = df[col].value_counts()
    
    # Mostrar solo los 3 primeros y 3 últimos resultados
    print(frecuencia.head(3))
    print("...")
    print(frecuencia.tail(3))
# Out:
#          DEPREG      MUPREG   MESREG  AÑOREG  DIAOCU     MESOCU  AÑOOCU  \
# 0     Escuintla    San José     Mayo  2021.0     1.0    Febrero  2021.0
# 1     Guatemala   Guatemala    Junio  2022.0    23.0     Agosto  2021.0
# 2    Retalhuleu  Retalhuleu  Octubre  2021.0    11.0    Octubre  2021.0
# 3     Guatemala   Guatemala    Enero  2022.0    29.0  Noviembre  2021.0
# 4  Baja Verapaz      Salamá    Marzo  2021.0    28.0      Enero  2021.0
#
#          DEPOCU      MUPOCU EDADHOM EDADMUJ           PPERHOM  \
# 0     Escuintla    San José    29.0    25.0  Ladino / Mestizo
# 1     Guatemala   Guatemala    36.0    37.0  Ladino / Mestizo
# 2    Retalhuleu  Retalhuleu    34.0    31.0  Ladino / Mestizo
# 3     Guatemala   Guatemala    48.0    33.0  Ladino / Mestizo
# 4  Baja Verapaz      Salamá    44.0    28.0  Ladino / Mestizo
#
#             PPERMUJ     NACHOM     NACMUJ         ESCHOM         ESCMUJ  \
# 0  Ladino / Mestizo  Guatemala  Guatemala  Diversificado  Diversificado
# ...

# %%
import pandas as pd

# Cargar el archivo SPSS (.sav)
archivo = "divorcios2020.sav"  # Asegúrate de que el archivo esté en la misma carpeta o usa la ruta completa
df = pd.read_spss(archivo)

# Mostrar las primeras filas
print(df.head())

# Mostrar información de las columnas (nombres y tipos de datos)
print(df.info())

# Seleccionar solo las columnas categóricas
columnas_categoricas = df.select_dtypes(include=['category']).columns

# Obtener tablas de frecuencia para cada variable categórica
for col in columnas_categoricas:
    print(f"\nFrecuencia de la variable '{col}':")
    frecuencia = df[col].value_counts()
    
    # Mostrar solo los 3 primeros y 3 últimos resultados
    print(frecuencia.head(3))
    print("...")
    print(frecuencia.tail(3))
# Out:
#            DEPREG               MUPREG      MESREG  AÑOREG  DIAOCU  \
# 0      Santa Rosa             Oratorio   Diciembre  2020.0    19.0
# 1          Sololá  Santa Lucía Utatlán     Febrero  2020.0     3.0
# 2  Quetzaltenango                Zunil  Septiembre  2020.0    21.0
# 3     Totonicapán          Totonicapán       Marzo  2021.0    18.0
# 4          Zacapa             La Unión   Noviembre  2020.0     9.0
#
#        MESOCU  AÑOOCU          DEPOCU               MUPOCU EDADHOM EDADMUJ  \
# 0   Noviembre  2020.0      Santa Rosa     Nueva Santa Rosa    19.0    23.0
# 1     Febrero  2020.0          Sololá  Santa Lucía Utatlán    20.0    20.0
# 2  Septiembre  2020.0  Quetzaltenango                Zunil    20.0    20.0
# 3   Noviembre  2020.0     Totonicapán          Totonicapán    20.0    21.0
# 4   Noviembre  2020.0          Zacapa             La Unión    20.0    22.0
#
#             PPERHOM           PPERMUJ     NACHOM     NACMUJ         ESCHOM  \
# ...

# %%
import pandas as pd

# Cargar el archivo SPSS (.sav)
archivo = "divorcios2019.sav"  # Asegúrate de que el archivo esté en la misma carpeta o usa la ruta completa
df = pd.read_spss(archivo)

# Mostrar las primeras filas
print(df.head())

# Mostrar información de las columnas (nombres y tipos de datos)
print(df.info())

# Seleccionar solo las columnas categóricas
columnas_categoricas = df.select_dtypes(include=['category']).columns

# Obtener tablas de frecuencia para cada variable categórica
for col in columnas_categoricas:
    print(f"\nFrecuencia de la variable '{col}':")
    frecuencia = df[col].value_counts()
    
    # Mostrar solo los 3 primeros y 3 últimos resultados
    print(frecuencia.head(3))
    print("...")
    print(frecuencia.tail(3))
# Out:
#          DEPREG     MUPREG     MESREG  AÑOREG  DIAOCU   MESOCU  AÑOOCU  \
# 0  Alta Verapaz      Cobán    Octubre  2019.0     5.0    Junio  2019.0
# 1     Guatemala      Mixco      Junio  2019.0    28.0     Mayo  2019.0
# 2     Guatemala  Guatemala  Noviembre  2019.0    24.0  Octubre  2019.0
# 3     Guatemala  Guatemala  Noviembre  2019.0    14.0  Octubre  2019.0
# 4     Guatemala  Guatemala  Noviembre  2019.0    26.0    Julio  2019.0
#
#          DEPOCU         MUPOCU EDADHOM   EDADMUJ           PPERHOM  \
# 0  Alta Verapaz          Cobán    50.0  Ignorado  Ladino / Mestizo
# 1     Guatemala      Guatemala    48.0      47.0  Ladino / Mestizo
# 2     Guatemala  Villa Canales    57.0      55.0  Ladino / Mestizo
# 3     Guatemala      Guatemala    42.0      39.0  Ladino / Mestizo
# 4     Guatemala          Mixco    54.0      31.0  Ladino / Mestizo
#
#             PPERMUJ     NACHOM     NACMUJ         ESCHOM         ESCMUJ  \
# ...

# %%
import pandas as pd

# Cargar el archivo SPSS (.sav)
archivo = "divorcios2018.sav"
df = pd.read_spss(archivo)

# Mostrar las primeras filas
print(df.head())

# Mostrar información de las columnas (nombres y tipos de datos)
print(df.info())

# Seleccionar solo las columnas categóricas
columnas_categoricas = df.select_dtypes(include=['category']).columns

# Obtener tablas de frecuencia para cada variable categórica
for col in columnas_categoricas:
    print(f"\nFrecuencia de la variable '{col}':")
    frecuencia = df[col].value_counts()
    
    # Mostrar solo los 3 primeros y 3 últimos resultados
    print(frecuencia.head(3))
    print("...")
    print(frecuencia.tail(3))
# Out:
#       DEPREG          MUPREG     MESREG  AÑOREG  DIAOCU     MESOCU  AÑOOCU  \
# 0  Guatemala       Fraijanes      Junio  2019.0     5.0  Diciembre  2018.0
# 1  Escuintla       La Gomera  Noviembre  2018.0    24.0      Julio  2018.0
# 2  Guatemala       Guatemala      Abril  2018.0     2.0      Abril  2018.0
# 3  Escuintla       Escuintla      Junio  2018.0     9.0      Marzo  2018.0
# 4     Izabal  Puerto Barrios     Agosto  2018.0     3.0      Abril  2018.0
#
#       DEPOCU         MUPOCU   EDADHOM   EDADMUJ   PPERHOM   PPERMUJ  \
# 0     Izabal        Morales  Ignorado  Ignorado  Ignorado  Ignorado
# 1  Escuintla      La Gomera  Ignorado  Ignorado  Ignorado  Ignorado
# 2  Guatemala      Guatemala  Ignorado  Ignorado  Ignorado  Ignorado
# 3  Escuintla      Escuintla  Ignorado  Ignorado  Ignorado  Ignorado
# 4    Jutiapa  Asunción Mita  Ignorado  Ignorado  Ignorado  Ignorado
#
#       NACHOM     NACMUJ   ESCHOM    ESCMUJ   CIUOHOM   CIUOMUJ
# ...

# %%
import pandas as pd

# Cargar el archivo SPSS (.sav)
archivo = "divorcios2017.sav"
df = pd.read_spss(archivo)

# Mostrar las primeras filas
print(df.head())

# Mostrar información de las columnas (nombres y tipos de datos)
print(df.info())

# Seleccionar solo las columnas categóricas
columnas_categoricas = df.select_dtypes(include=['category']).columns

# Obtener tablas de frecuencia para cada variable categórica
for col in columnas_categoricas:
    print(f"\nFrecuencia de la variable '{col}':")
    frecuencia = df[col].value_counts()
    
    # Mostrar solo los 3 primeros y 3 últimos resultados
    print(frecuencia.head(3))
    print("...")
    print(frecuencia.tail(3))
# Out:
#         DEPREG       MUPREG      MESREG  AÑOREG  DIAOCU     MESOCU  AÑOOCU  \
# 0  Totonicapan  Totonicapán   Diciembre  2017.0     4.0  Diciembre  2017.0
# 1    Guatemala    Guatemala  Septiembre  2017.0     5.0     Agosto  2017.0
# 2    Guatemala    Guatemala       Julio  2017.0    23.0       Mayo  2017.0
# 3    Guatemala    Guatemala     Octubre  2017.0     7.0      Julio  2017.0
# 4    Guatemala    Guatemala   Diciembre  2017.0    20.0      Julio  2017.0
#
#         DEPOCU       MUPOCU   EDADHOM   EDADMUJ           PPERHOM  \
# 0  Totonicapan  Totonicapán      47.0  Ignorado          Ignorado
# 1    Guatemala    Guatemala  Ignorado  Ignorado          Ignorado
# 2    Guatemala    Guatemala      33.0      31.0  Ladino / Mestizo
# 3    Guatemala    Guatemala  Ignorado  Ignorado          Ignorado
# 4    Guatemala    Guatemala  Ignorado  Ignorado          Ignorado
#
#             PPERMUJ      NACHOM     NACMUJ    ESCHOM    ESCMUJ  \
# ...

# %%
import pandas as pd

# Cargar el archivo SPSS (.sav)
archivo = "divorcios2016.sav"
df = pd.read_spss(archivo)

# Mostrar las primeras filas
print(df.head())

# Mostrar información de las columnas (nombres y tipos de datos)
print(df.info())

# Seleccionar solo las columnas categóricas
columnas_categoricas = df.select_dtypes(include=['category']).columns

# Obtener tablas de frecuencia para cada variable categórica
for col in columnas_categoricas:
    print(f"\nFrecuencia de la variable '{col}':")
    frecuencia = df[col].value_counts()
    
    # Mostrar solo los 3 primeros y 3 últimos resultados
    print(frecuencia.head(3))
    print("...")
    print(frecuencia.tail(3))
# Out:
#       DEPREG     MUPREG     MESREG  AÑOREG  DIAOCU     MESOCU  AÑOOCU  \
# 0  Guatemala  Guatemala  Diciembre  2016.0     3.0  Noviembre  2016.0
# 1  Guatemala  Guatemala     Agosto  2016.0    17.0       Mayo  2016.0
# 2      Peten     Flores     Agosto  2016.0    11.0     Agosto  2016.0
# 3  Guatemala  Guatemala      Marzo  2017.0     7.0    Octubre  2016.0
# 4     Zacapa  Teculután    Febrero  2017.0    23.0  Noviembre  2016.0
#
#         DEPOCU     MUPOCU   EDADHOM   EDADMUJ   PPERHOM           PPERMUJ  \
# 0    Guatemala  Guatemala  Ignorado  Ignorado  Ignorado          Ignorado
# 1    Guatemala  Guatemala      58.0  Ignorado  Ignorado          Ignorado
# 2    Guatemala  Guatemala      61.0      53.0  Ignorado          Ignorado
# 3    Guatemala  Guatemala      39.0      38.0  Ignorado  Mestizo / Ladino
# 4  El Progreso   Sanarate  Ignorado  Ignorado  Ignorado          Ignorado
#
#       NACHOM     NACMUJ    ESCHOM         ESCMUJ  \
# ...

# %%
import pandas as pd

# Cargar el archivo SPSS (.sav)
archivo = "divorcios2015.sav"
df = pd.read_spss(archivo)

# Mostrar las primeras filas
print(df.head())

# Mostrar información de las columnas (nombres y tipos de datos)
print(df.info())

# Seleccionar solo las columnas categóricas
columnas_categoricas = df.select_dtypes(include=['category']).columns

# Obtener tablas de frecuencia para cada variable categórica
for col in columnas_categoricas:
    print(f"\nFrecuencia de la variable '{col}':")
    frecuencia = df[col].value_counts()
    
    # Mostrar solo los 3 primeros y 3 últimos resultados
    print(frecuencia.head(3))
    print("...")
    print(frecuencia.tail(3))
# Out:
#       DEPREG       MUPREG   MESREG  AÑOREG  DIAOCU     MESOCU  AÑOOCU  \
# 0  Guatemala    Guatemala   Agosto  2015.0    17.0      Julio  2015.0
# 1  Guatemala    Guatemala    Junio  2016.0    29.0      Julio  2015.0
# 2     Zacapa       Zacapa  Febrero  2016.0     8.0      Julio  2015.0
# 3  Guatemala    Guatemala  Febrero  2016.0    22.0  Diciembre  2015.0
# 4    Jutiapa  Agua Blanca  Febrero  2015.0     3.0    Febrero  2015.0
#
#           DEPOCU         MUPOCU   EDADHOM   EDADMUJ            PUEHOM  \
# 0  Huehuetenango  Huehuetenango  Ignorado  Ignorado          Ignorado
# 1      Guatemala      Guatemala  Ignorado  Ignorado          Ignorado
# 2         Zacapa         Zacapa      46.0      40.0  Mestizo / ladino
# 3      Guatemala    Villa Nueva  Ignorado  Ignorado          Ignorado
# 4        Jutiapa   Yupiltepeque  Ignorado  Ignorado  Mestizo / ladino
#
#              PUEMUJ                     NACHOM     NACMUJ   ESCHOM    ESCMUJ  \
# ...

# %%
import pandas as pd

# Cargar el archivo SPSS (.sav)
archivo = "divorcios2014.sav"
df = pd.read_spss(archivo)

# Mostrar las primeras filas
print(df.head())

# Mostrar información de las columnas (nombres y tipos de datos)
print(df.info())

# Seleccionar solo las columnas categóricas
columnas_categoricas = df.select_dtypes(include=['category']).columns

# Obtener tablas de frecuencia para cada variable categórica
for col in columnas_categoricas:
    print(f"\nFrecuencia de la variable '{col}':")
    frecuencia = df[col].value_counts()
    
    # Mostrar solo los 3 primeros y 3 últimos resultados
    print(frecuencia.head(3))
    print("...")
    print(frecuencia.tail(3))
# Out:
#           DEPREG                    MUPREG      MESREG  AÑOREG  DIAOCU  \
# 0         Zacapa                    Zacapa       Julio  2014.0     6.0
# 1  Suchitepequez               Mazatenango       Abril  2014.0    10.0
# 2      Guatemala                 Guatemala  Septiembre  2014.0     4.0
# 3   Sacatepequez  Santa Lucía Milpas Altas       Enero  2015.0     7.0
# 4  Suchitepequez               Mazatenango        Mayo  2014.0     4.0
#
#    MESOCU         DEPOCU                    MUPOCU   EDADHOM   EDADMUJ  \
# 0   Junio         Zacapa                    Zacapa  Ignorado  Ignorado
# 1   Marzo  Suchitepequez               Mazatenango  Ignorado  Ignorado
# 2  Agosto   Sacatepequez         Antigua Guatemala  Ignorado  Ignorado
# 3  Agosto   Sacatepequez  Santa Lucía Milpas Altas      30.0      27.0
# 4   Abril  Suchitepequez               Mazatenango  Ignorado  Ignorado
#
#              PUEHOM            PUEMUJ  NACHOM     NACMUJ    ESCHOM    ESCMUJ  \
# ...

# %%
import pandas as pd

# Cargar el archivo SPSS (.sav)
archivo = "divorcios2013.sav"
df = pd.read_spss(archivo)

# Mostrar las primeras filas
print(df.head())

# Mostrar información de las columnas (nombres y tipos de datos)
print(df.info())

# Seleccionar solo las columnas categóricas
columnas_categoricas = df.select_dtypes(include=['category']).columns

# Obtener tablas de frecuencia para cada variable categórica
for col in columnas_categoricas:
    print(f"\nFrecuencia de la variable '{col}':")
    frecuencia = df[col].value_counts()
    
    # Mostrar solo los 3 primeros y 3 últimos resultados
    print(frecuencia.head(3))
    print("...")
    print(frecuencia.tail(3))
# Out:
#            DEPREG     MUPREG      MESREG  AÑOREG  DIAOCU  MESOCU  \
# 0       Guatemala      Mixco       Julio  2013.0    25.0   Marzo
# 1         Jutiapa     Moyuta  Septiembre  2013.0    27.0  Agosto
# 2  Quetzaltenango    Colomba     Octubre  2013.0    26.0   Julio
# 3       Guatemala  Guatemala       Julio  2013.0    29.0   Abril
# 4       Guatemala  Guatemala       Enero  2013.0     4.0   Enero
#
#            DEPOCU      MUPOCU EDADHOM EDADMUJ            PUEHOM  \
# 0       Guatemala   Guatemala    55.0    35.0  Mestizo / ladino
# 1         Jutiapa     Jutiapa    46.0    36.0  Mestizo / ladino
# 2  Quetzaltenango  Coatepeque    27.0    28.0  Mestizo / ladino
# 3       Guatemala   Amatitlán    42.0    35.0  Mestizo / ladino
# 4       Guatemala   Guatemala    43.0    34.0  Mestizo / ladino
#
#              PUEMUJ     NACHOM     NACMUJ         ESCHOM    ESCMUJ  \
# 0          Ignorado  Guatemala  Guatemala      Postgrado  Ignorado
# ...
